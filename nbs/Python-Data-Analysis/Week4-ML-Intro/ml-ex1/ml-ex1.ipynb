# %% [markdown]
# # Linear regression

# %% [markdown]
# ![Photo By DATAIDEA](banner4.png)

# %% [markdown]
# This exercise is described in [ex1.pdf](ex1.pdf).

# %% [markdown]
# <!-- Newsletter -->
# <div style="background-color: #3a6e68; border:1px solid #3a6e68; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>Don't Miss Any Updates!</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
#
# <p class=pb-1>
# Before you continue, we have a humble request. To be among the first to hear about future updates of the course materials, simply enter your email below, follow us on <a href="https://x.com/dataideaorg"><i class="bi bi-twitter-x"></i>
#  (formally Twitter)</a>, or subscribe to our <a href="https://www.youtube.com/@dataideaorg"><i class="bi bi-youtube"></i> YouTube channel</a>.
# </p>
#
# <iframe src="https://embeds.beehiiv.com/5fc7c425-9c7e-4e08-a514-ad6c22beee74?slim=true" data-test-id="beehiiv-embed" height="52" frameborder="0" scrolling="no" style="margin: 0; border-radius: 0px !important; background-color: transparent; width: 100%;" ></iframe>
# </div>

# %% [markdown]
# ### Load packages here

# %%
# your solution

# %% [markdown]
# ## Linear regression with one variable

# %% [markdown]
# ### Load data from CSV file
#
# - column 1: population (x)
# - column 2: profit (y)

# %%
# your solution

# %% [markdown]
# ### Separate features (x) from target (y)

# %%
# your solution

# %% [markdown]
# ### Display the Number of examples

# %%
# your solution

# %% [markdown]
# ### Fit a linear regression model (without regularization)

# %%
# your solution

# %% [markdown]
# ### Obtain coefficients theta0 and theta1 from model

# %%
# your solution

# %% [markdown]
# ### Plot data and regression line

# %%
# your solution

# %% [markdown]
# ### Obtain your Training mean squared error

# %%
# your solution

# %% [markdown]
# ### Obtain the Training score

# %%
# your solution

# %% [markdown]
# ### Predict profit for populations of 35.000 and 70.000

# %%
# your solution

# %% [markdown]
# ### Linear regression with multiple variables

# %% [markdown]
# ### Load data from CSV file
#
# - column 1: house size in feet**2 (x1)
# - column 2: number of bedrooms (x2)
# - column 3: house price (y)

# %%
# your solution

# %% [markdown]
# ### Separate features (x1, x2) from target (y)

# %%
# your solution

# %% [markdown]
# ### Find the Number of examples

# %%
# your solution

# %% [markdown]
# ### Pipeline components
# Pipeline of feature scaler and linear regressor

# %%
# your solution

# %% [markdown]
# ### Run linear regression on scaled features

# %%
# your solution

# %% [markdown]
# ### Obtain your Training mean squared error

# %%
# your score

# %% [markdown]
# ### What is the Training score

# %% [markdown]
# <!-- Comments -->
# ### Comments
# <script src="https://utteranc.es/client.js"
#         repo="dataideaorg/dataidea-blog"
#         issue-term="pathname"
#         theme="github-light"
#         crossorigin="anonymous"
#         async>
# </script>

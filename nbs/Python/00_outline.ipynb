# %% [markdown]
# ---
# title: Python3 Outline
# author: Juma Shafara
# date: "2023-11"
# description: Python 3 Beginner Course Outline
# keywords: [Python Course Outline]
# ---

# %% [markdown]
# ![Photo by DATAIDEA](../assets/banner4.png)

# %% [markdown]
# ## Basics [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./01_basics.ipynb)
# - Python Overview
# - Introduction
# - Installing
# - Writing Code
# - Displaying Output
# - Statements
# - Syntax
# - Comments
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./01_basics.ipynb)

# %% [markdown]
# ## Variables [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./02_variables.ipynb)
# - Variables
# - Data Types
# - Numbers
# - Number Methods
# - Strings
# - Type Conversion
# - Python Booleans
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./02_variables.ipynb)

# %% [markdown]
# ## Operations [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./04_operators.ipynb)
# - Operators Intro
# - Arithmetics
# - Assignment
# - Comparison
# - Logical
# - Identity
# - Membership
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./04_operators.ipynb)

# %% [markdown]
# ## Collections [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./05_containers.ipynb)
# - Containers
# - List
# - Tuple
# - Set
# - Dictionary
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./05_containers.ipynb)

# %% [markdown]
# ## Flow Control [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./06_flow_control.ipynb)
# - Functions
# - Lambda functions
# - If else
# - If else shorthand
# - For Loop
# - While Loop
# - Break and Continue
# - Pass
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./06_flow_control.ipynb)

# %% [markdown]
# ## Advanced [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./07_advanced.ipynb)
# - Functions
# - Classes and Objects
# - Inheritance
# - Variable Scope
# - Formatting Strings
# - Try … Except
# - Iterators
# - User Input
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./07_advanced.ipynb)

# %% [markdown]
# ## Modules [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./08_modules.ipynb)
# - Intro
# - Math
# - Random
# - Date and Time
# - JSON
# - Regular Expressions
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./08_modules.ipynb)

# %% [markdown]
# ## Working With Files [<i class="bi bi-arrow-right-circle" title="Get Started"></i>](./09_file_handling.ipynb)
# - Intro
# - File Handling
# - File Reading
# - File Writing/Creating/Appending
# - File Deleting
# - Exercise
#
# [Get Started <i class="bi bi-arrow-right-circle"></i>](./09_file_handling.ipynb)

# %% [markdown]
# <div class="p-3">
# <p class=pb-1>
# Don't miss out on any updates and developments! Subscribe to the DATAIDEA Newsletter it's easy and safe.
# </p>
# <iframe src="https://embeds.beehiiv.com/5fc7c425-9c7e-4e08-a514-ad6c22beee74?slim=true" data-test-id="beehiiv-embed" height="52" frameborder="0" scrolling="no" style="margin: 0; border-radius: 0px !important; background-color: transparent; width: 100%;" ></iframe>
#
# <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js?client=ca-pub-8076040302380238"
#      crossorigin="anonymous"></script>
# <!-- inline_horizontal -->
# <ins class="adsbygoogle"
#      style="display:block"
#      data-ad-client="ca-pub-8076040302380238"
#      data-ad-slot="9021194372"
#      data-ad-format="auto"
#      data-full-width-responsive="true"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>

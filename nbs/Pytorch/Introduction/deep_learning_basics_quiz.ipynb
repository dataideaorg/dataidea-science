# %% [markdown]
# ---
# title: Deep Learning Basics Quiz
# author: Juma Shafara
# date: "2024-02"
# date-modified: "2024-07-25"
# description:
# keywords: []
# ---

# %% [markdown]
# ![Photo by DATAIDEA](../assets/banner4.png)

# %% [markdown]
# Here’s a set of objective-type quiz questions on deep learning:
#
# ## 1. Which of the following is a popular framework for deep learning?
# a) TensorFlow
# b) Pandas
# c) NumPy
# d) SciPy
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">a.Tensorflow.</p>
# </details>

# %% [markdown]
# <!-- Newsletter -->
# <div style="background-color: #3a6e68; border:1px solid #3a6e68; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>Don't Miss Any Updates!</strong></div>
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
#
# <p class=pb-1>
# Before we continue, we have a humble request, to be among the first to hear about future updates of the course materials, simply enter your email below, follow us on <a href="https://x.com/dataideaorg"><i class="bi bi-twitter-x"></i>
#  (formally Twitter)</a>, or subscribe to our <a href="https://www.youtube.com/@dataideaorg"><i class="bi bi-youtube"></i> YouTube channel</a>.
# </p>
#
# <iframe src="https://embeds.beehiiv.com/5fc7c425-9c7e-4e08-a514-ad6c22beee74?slim=true" data-test-id="beehiiv-embed" height="52" frameborder="0" scrolling="no" style="margin: 0; border-radius: 0px !important; background-color: transparent; width: 100%;" ></iframe>
# </div>
#
# ## 2. What is the main purpose of activation functions in neural networks?
# a) To initialize weights
# b) To introduce non-linearity
# c) To reduce overfitting
# d) To increase the number of layers
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">b.To introduce non-linearity </p>
# </details>
#
# ## 3. In the context of deep learning, what does CNN stand for?
# a) Convolutional Neural Network
# b) Central Neural Network
# c) Circular Neural Network
# d) Cross Neural Network
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">a.Convolutional Neural Network</p>
# </details>
#
# ## 4. Which of the following is NOT a type of gradient descent algorithm?
# a) Stochastic Gradient Descent
# b) Batch Gradient Descent
# c) Mini-Batch Gradient Descent
# d) Sequential Gradient Descent
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">d.Sequential Gradient Descent</p>
# </details>
#
# ## 5. What is the role of dropout in a neural network?
# a) To increase the learning rate
# b) To prevent overfitting
# c) To add more layers to the network
# d) To decrease the training time
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">b.To prevent overfitting</p>
# </details>
#
# ## 6. In the context of RNNs, what does LSTM stand for?
# a) Long Short-Term Memory
# b) Long Stable-Time Memory
# c) Large Scale-Time Memory
# d) Large Short-Term Memory
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">a.Long Short-Term Memory</p>
# </details>
#
# ## 7. Which of the following is a common loss function used for classification tasks?
# a) Mean Squared Error
# b) Cross-Entropy Loss
# c) Hinge Loss
# d) Mean Absolute Error
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">b.Cross-Entropy Loss</p>
# </details>
#
# ## 8. Which type of neural network is primarily used for sequence prediction tasks?
# a) Convolutional Neural Network
# b) Recurrent Neural Network
# c) Feedforward Neural Network
# d) Radial Basis Function Network
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">b.Recurrent Neural Network</p>
# </details>
#
# ## 9. What is backpropagation primarily used for in neural networks?
# a) Forward pass computation
# b) Weight initialization
# c) Error minimization
# d) Data normalization
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">c.Error minimization</p>
# </details>
#
# ## 10. In a neural network, what is the purpose of a softmax layer?
# a) To perform linear regression
# b) To scale inputs to a range between 0 and 1
# c) To convert logits into probabilities
# d) To reduce dimensionality
#
# <details class="mb-2">
# <summary style="color: #3a6e68;">
#     <b>Reveal answer</b>
# </summary>
# <p class="alert alert-success">c.To convert logits into probabilities</p>
# </details>

# %% [markdown]
# <h2>What's on your mind? Put it in the comments!</h2>
# <script src="https://utteranc.es/client.js"
#         repo="dataideaorg/dataidea-science"
#         issue-term="pathname"
#         theme="github-light"
#         crossorigin="anonymous"
#         async>
# </script>
